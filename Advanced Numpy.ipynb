# %% [markdown]
# ## Working with mathematical Formulas

# %%
import numpy as np
a = np.arange(10)
np.sum(a)
# Out:
# 45

# %% [markdown]
# #### Sigmoid
# #### Mean squared error
# #### Categorial cross entropy

# %% [markdown]
# # Sigmoid
# ![image.png](attachment:6671dfce-72d6-43ac-b51b-be4aa9a5ca49.png)

# %%
# Sigmoid
def sigmoid(array):
    return 1/(1+ np.exp(-(array)))

a  = np.arange(10)
sigmoid(a)
# Out:
# array([0.5       , 0.73105858, 0.88079708, 0.95257413, 0.98201379,
#        0.99330715, 0.99752738, 0.99908895, 0.99966465, 0.99987661])

# %% [markdown]
# # Mean Squared Error
# ![image.png](attachment:3ecfb357-f177-4c75-8511-222837b94006.png)

# %%
#  Mean squared error
actual = np.random.randint(1,50,25)
predicted = np.random.randint(1,50,25)

mse =  np.mean((actual-predicted)**2)
mse
# Out:
# 555.16

# %% [markdown]
# ## Working with missing values

# %%
a = np.array([1,2,3,4,np.nan,6])  ## Here nan ans none is two diff thing
print(a)
# Out:
# [ 1.  2.  3.  4. nan  6.]

# %%
a[~(np.isnan(a))]
# Out:
# array([1., 2., 3., 4., 6.])
